# %%
# %%bash
# pip install nltk
# pip install datasets
# pip install transformers[torch]
# pip install tokenizers
# pip install evaluate
# pip install rouge_score
# pip install sentencepiece
# pip install huggingface_hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/glados/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: joblib in /home/glados/.local/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: tqdm in /home/glados/.local/lib/python3.10/site-packages (from nltk) (4.66.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/glados/.local/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: click in /home/glados/.local/lib/python3.10/site-packages (from nltk) (8.1.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/glados/.local/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets) (5.4.1)
# Requirement already satisfied: pyarrow-hotfix in /home/glados/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (2024.2.0)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (0.21.4)
# Requirement already satisfied: pandas in /home/glados/.local/lib/python3.10/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: numpy>=1.17 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: packaging in /home/glados/.local/lib/python3.10/site-packages (from datasets) (24.0)
# Requirement already satisfied: filelock in /home/glados/.local/lib/python3.10/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: tqdm>=4.62.1 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (4.66.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: xxhash in /home/glados/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/glados/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in /home/glados/.local/lib/python3.10/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: requests>=2.19.0 in /home/glados/.local/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/glados/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/glados/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/glados/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/glados/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers[torch] in /home/glados/.local/lib/python3.10/site-packages (4.38.2)
# Requirement already satisfied: packaging>=20.0 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: numpy>=1.17 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (1.26.4)
# Requirement already satisfied: requests in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (4.66.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (0.21.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (0.15.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers[torch]) (5.4.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (0.4.2)
# Requirement already satisfied: filelock in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: torch in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (2.2.1)
# Requirement already satisfied: accelerate>=0.21.0 in /home/glados/.local/lib/python3.10/site-packages (from transformers[torch]) (0.28.0)
# Requirement already satisfied: psutil in /home/glados/.local/lib/python3.10/site-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/glados/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/glados/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.10.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (2.2.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: sympy in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: jinja2 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (3.1.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: networkx in /home/glados/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (3.2.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/glados/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.4.99)
# Requirement already satisfied: idna<4,>=2.5 in /home/glados/.local/lib/python3.10/site-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/glados/.local/lib/python3.10/site-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/glados/.local/lib/python3.10/site-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/glados/.local/lib/python3.10/site-packages (from requests->transformers[torch]) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/glados/.local/lib/python3.10/site-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/glados/.local/lib/python3.10/site-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tokenizers in /home/glados/.local/lib/python3.10/site-packages (0.15.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /home/glados/.local/lib/python3.10/site-packages (from tokenizers) (0.21.4)
# Requirement already satisfied: filelock in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (4.10.0)
# Requirement already satisfied: requests in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers) (4.66.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers) (2024.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: evaluate in /home/glados/.local/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: requests>=2.19.0 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: datasets>=2.0.0 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (2.18.0)
# Requirement already satisfied: pandas in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (2.2.1)
# Requirement already satisfied: packaging in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (24.0)
# Requirement already satisfied: responses<0.19 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: xxhash in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (2024.2.0)
# Requirement already satisfied: dill in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (0.21.4)
# Requirement already satisfied: multiprocess in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: tqdm>=4.62.1 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (4.66.2)
# Requirement already satisfied: numpy>=1.17 in /home/glados/.local/lib/python3.10/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: aiohttp in /home/glados/.local/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: filelock in /home/glados/.local/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets>=2.0.0->evaluate) (5.4.1)
# Requirement already satisfied: pyarrow-hotfix in /home/glados/.local/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/glados/.local/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (15.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/glados/.local/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.10.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/glados/.local/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/glados/.local/lib/python3.10/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/glados/.local/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/glados/.local/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/glados/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rouge_score in /home/glados/.local/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /home/glados/.local/lib/python3.10/site-packages (from rouge_score) (2.1.0)
# Requirement already satisfied: numpy in /home/glados/.local/lib/python3.10/site-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: nltk in /home/glados/.local/lib/python3.10/site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/lib/python3/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /home/glados/.local/lib/python3.10/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: tqdm in /home/glados/.local/lib/python3.10/site-packages (from nltk->rouge_score) (4.66.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/glados/.local/lib/python3.10/site-packages (from nltk->rouge_score) (2023.12.25)
# Requirement already satisfied: joblib in /home/glados/.local/lib/python3.10/site-packages (from nltk->rouge_score) (1.3.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentencepiece in /home/glados/.local/lib/python3.10/site-packages (0.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: huggingface_hub in /home/glados/.local/lib/python3.10/site-packages (0.21.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface_hub) (5.4.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: filelock in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: packaging>=20.9 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: requests in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub) (4.10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/glados/.local/lib/python3.10/site-packages (from huggingface_hub) (2024.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/glados/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (3.3.2)

# %% [markdown]
# https://www.datacamp.com/tutorial/flan-t5-tutorial

# %%
import nltk
import evaluate
import numpy as np
from datasets import load_dataset
from transformers import T5Tokenizer, DataCollatorForSeq2Seq
from transformers import T5ForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
# Load the tokenizer, model, and data collator
MODEL_NAME = "google/flan-t5-xl"

tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/53.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
